# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
df = pd.read_csv('/Users/nathandhawale/Documents/CodingDojo/Coding/Data-Enrichment/Medical.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               995 non-null    object
#  1   Lat                 1000 non-null   float64
#  2   Lng                 1000 non-null   float64
#  3   Area                995 non-null    object
#  4   Children            993 non-null    float64
#  5   Age                 1000 non-null   int64
#  6   Income              1000 non-null   float64
#  7   Marital             995 non-null    object
#  8   Gender              995 non-null    object
#  9   ReAdmis             1000 non-null   int64
#  10  VitD_levels         1000 non-null   float64
#  11  Doc_visits          1000 non-null   int64
#  12  Full_meals_eaten    1000 non-null   int64
#  13  vitD_supp           1000 non-null   int64
#  14  Soft_drink          1000 non-null   int64
# ...

# %% [markdown]
# Vitamin D levels are continuous and is not skewed either direction. This is mesokurtic.

# %%
col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature, kde = True)
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend()

# %% [markdown]
# Doc visits are discrete and is positively skewed. This is Leptokurtic.

# %%
col1 = 'Doc_visits'
feature1 = df[col1]
mean1 = feature1.mean()
median1 = feature1.median()
std1 = feature1.std()
plus_one_std1 = mean1 + std1
minus_one_std1 = mean1 - std1
fig,ax1 = plt.subplots(figsize=(10,6))
sns.histplot(feature1, kde = True)
ax1.axvline(mean1, color = 'red',label=f'Mean = {mean1:,.2f}')
ax1.axvline(median1, color = 'green', label = f'Median = {median1:,.2f}')
ax1.axvline(plus_one_std1, color = 'black',label=f'+1 std = {plus_one_std1:,.2f}')
ax1.axvline(minus_one_std1, color = 'black', label = f'-1 std = {minus_one_std1:,.2f}')
ax1.axvspan(plus_one_std1, minus_one_std1, color = 'yellow', zorder = 0)
ax1.set_title(f'{col1}')
ax1.legend()

# %% [markdown]
# Total charge is continuous and is positively skewed. This is mesokurtic.

# %%
col2 = 'TotalCharge'
feature2 = df[col2]
mean2 = feature2.mean()
median2 = feature2.median()
std2 = feature2.std()
plus_one_std2 = mean2 + std2
minus_one_std2 = mean2 - std2
fig,ax2 = plt.subplots(figsize=(10,6))
sns.histplot(feature2, kde = True)
ax2.axvline(mean2, color = 'red',label=f'Mean = {mean2:,.2f}')
ax2.axvline(median2, color = 'green', label = f'Median = {median2:,.2f}')
ax2.axvline(plus_one_std2, color = 'black',label=f'+1 std = {plus_one_std2:,.2f}')
ax2.axvline(minus_one_std2, color = 'black', label = f'-1 std = {minus_one_std2:,.2f}')
ax2.axvspan(plus_one_std2, minus_one_std2, color = 'yellow', zorder = 0)
ax2.set_title(f'{col2}')
ax2.legend()
